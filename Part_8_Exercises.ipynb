# %% [markdown]
# # Part 8: Exercises
#
# Test your knowledge with these TensorFlow 2.x exercises!

# %% [markdown]
# ### Exercise 1: Tensor Manipulation
# Create a 3x3 matrix of random normal values and find the mean of each row.

# %%
import tensorflow as tf

# Your code here

# %% [markdown]
# ### Exercise 2: Linear Regression
# Modify the code from Part 4 to use a different optimizer (e.g., `Adam`) and see how it affects training speed.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3: Functional API
# Create a model with two inputs that are concatenated before being passed to a Dense layer.

# %%
from tensorflow.keras import layers

# Your code here
